# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls -la "/content/gdrive/My Drive/darknet"
# Out:
# total 158713
# drwx------ 2 root root      4096 Sep 11  2020 backup
# drwx------ 2 root root      4096 Apr  8  2020 cuDNN
# -rw------- 1 root root 162482580 Jul 19  2020 darknet53.conv.74
# -rw------- 1 root root       221 Jan 21 15:49 obj.data
# -rw------- 1 root root        62 Jan 21 15:49 obj.names
# drwx------ 2 root root      4096 Jan 27 10:16 output
# drwx------ 2 root root      4096 Jan 21 15:55 stock
# -rw------- 1 root root      9118 Jan 21 15:51 stock.cfg
# drwx------ 2 root root      4096 Jan 27 10:13 test_images
# -rw------- 1 root root       821 Jan 21 16:00 test.txt
# -rw------- 1 root root      7462 Jan 21 16:00 train.txt

# %%
# !sudo apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (175 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# ...

# %%
# !tree /content/gdrive/My\ Drive/darknet/
# Out:
# /content/gdrive/My Drive/darknet/
# ├── backup
# │   ├── stock_1000.weights
# │   ├── stock_2000.weights
# │   ├── stock_3000.weights
# │   ├── stock_4000.weights
# │   ├── stock_5000.weights
# │   └── stock_last.weights
# ├── cuDNN
# │   └── cudnn-10.0-linux-x64-v7.5.0.56.tgz
# ├── darknet53.conv.74
# ├── obj.data
# ├── obj.names
# ├── output
# │   └── output.png
# ├── stock
# │   ├── 5PAISA_13_01_2021_12_12_38_108927_1W.png
# │   ├── 5PAISA_13_01_2021_12_12_38_108927_1W.txt
# │   ├── AARVEEDEN_13_01_2021_14_24_44_298950_1W.png
# │   ├── AARVEEDEN_13_01_2021_14_24_44_298950_1W.txt
# │   ├── ADORWELD_13_01_2021_16_36_08_995069_1W.png
# │   ├── ADORWELD_13_01_2021_16_36_08_995069_1W.txt
# │   ├── AGARIND_13_01_2021_12_10_01_814970_1W.png
# │   ├── AGARIND_13_01_2021_12_10_01_814970_1W.txt
# │   ├── AKSHARCHEM_13_01_2021_16_00_58_418915_1W.png
# │   ├── AKSHARCHEM_13_01_2021_16_00_58_418915_1W.txt
# │   ├── AKSHOPTFBR_13_01_2021_17_22_42_302720_1W.png
# ...

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !tar -xzvf gdrive/My\ Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a

# %%
# !chmod a+r /usr/local/cuda/include/cudnn.h

# %%
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

# Check the folder
# !ls

# I have a branch where I have done the changes commented above
# !git checkout feature/google-colab

#Compile Darknet
# !make

#Copies the Darknet compiled version to Google drive
# !cp ./darknet /content/gdrive/My\ Drive/darknet/bin/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.13 MiB | 25.17 MiB/s, done.
# Resolving deltas: 100% (6742/6742), done.
# /content/darknet/darknet
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md
# Branch 'feature/google-colab' set up to track remote branch 'feature/google-colab' from 'origin'.
# Switched to a new branch 'feature/google-colab'
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# ...

# %%
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/stock.cfg" "/content/gdrive/My Drive/darknet/darknet53.conv.74" -dont_show -mjpeg_port 8090 -map
# Out:
# /bin/bash: ./darknet: No such file or directory
