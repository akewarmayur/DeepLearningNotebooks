# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from IPython import display
from google.colab.patches import cv2_imshow

# %%
# !pip install ultralytics
# !pip install super_gradients
display.clear_output()

# %%
from ultralytics import YOLO
import cv2
model = YOLO("yolov8s.pt")
results = model.predict(source="/content/gdrive/My Drive/demoM/test_images/1.png", show=True)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to yolov8s.pt...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 172MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/gdrive/My Drive/demoM/test_images/1.png: 384x640 2 persons, 1 surfboard, 1 bottle, 3 cups, 1 dining table, 64.2ms
# Speed: 11.7ms preprocess, 64.2ms inference, 34.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 366MB/s]
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# Downloading https://ultralytics.com/images/bus.jpg to bus.jpg...
# 100% 476k/476k [00:00<00:00, 119MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 67.5ms
# Speed: 3.6ms preprocess, 67.5ms inference, 82.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
img = cv2.imread("runs/detect/predict/bus.jpg")
cv2_imshow(img)

# %%
# !pip install super_gradients
display.clear_output()

# %%
import super_gradients
yolo_nas = super_gradients.training.models.get("yolo_nas_l", pretrained_weights="coco").cuda()
yolo_nas.predict("https://deci-pretrained-models.s3.amazonaws.com/sample_images/beatles-abbeyroad.jpg").show()
