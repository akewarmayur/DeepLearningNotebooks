# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-lashsh57
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-lashsh57
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for segment-anything: filename=segment_anything-1.0-py3-none-any.whl size=36589 sha256=0419acc5faf5e5062d0fb2535cf095bc56158f6891b544878d0f8433f6cb71d9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yllqbdob/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment-anything
# ...

# %%
# !git clone https://github.com/5663015/segment_anything_webui.git
# Out:
# Cloning into 'segment_anything_webui'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 76 (delta 31), reused 62 (delta 17), pack-reused 0
# Unpacking objects: 100% (76/76), 7.76 MiB | 10.46 MiB/s, done.

# %%
cd segment_anything_webui
# Out:
# /content/segment_anything_webui

# %%
mkdir checkpoints

# %%
cd checkpoints
# Out:
# /content/segment_anything_webui/checkpoints

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# --2023-06-08 06:04:29--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 18.160.249.12, 18.160.249.77, 18.160.249.45, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|18.160.249.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘sam_vit_h_4b8939.pth’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G   245MB/s    in 10s
#
# 2023-06-08 06:04:40 (243 MB/s) - ‘sam_vit_h_4b8939.pth’ saved [2564550879/2564550879]

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_l_0b3195.pth
# Out:
# --2023-06-08 06:04:53--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_l_0b3195.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 18.160.249.12, 18.160.249.77, 18.160.249.45, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|18.160.249.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1249524607 (1.2G) [binary/octet-stream]
# Saving to: ‘sam_vit_l_0b3195.pth’
#
# sam_vit_l_0b3195.pt 100%[===================>]   1.16G   222MB/s    in 5.2s
#
# 2023-06-08 06:04:59 (230 MB/s) - ‘sam_vit_l_0b3195.pth’ saved [1249524607/1249524607]

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Out:
# --2023-06-08 06:05:11--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 18.160.249.45, 18.160.249.78, 18.160.249.77, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|18.160.249.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375042383 (358M) [binary/octet-stream]
# Saving to: ‘sam_vit_b_01ec64.pth’
#
# sam_vit_b_01ec64.pt 100%[===================>] 357.67M   229MB/s    in 1.6s
#
# 2023-06-08 06:05:13 (229 MB/s) - ‘sam_vit_b_01ec64.pth’ saved [375042383/375042383]

# %%
mkdir models--google--owlvit-base-patch32

# %%
cd models--google--owlvit-base-patch32
# Out:
# /content/segment_anything_webui/checkpoints/models--google--owlvit-base-patch32

# %%
# !wget https://huggingface.co/google/owlvit-base-patch32
# Out:
# --2023-06-08 06:06:05--  https://huggingface.co/google/owlvit-base-patch32
# Resolving huggingface.co (huggingface.co)... 18.160.249.70, 18.160.249.9, 18.160.249.78, ...
# Connecting to huggingface.co (huggingface.co)|18.160.249.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91153 (89K) [text/html]
# Saving to: ‘owlvit-base-patch32’
#
# owlvit-base-patch32 100%[===================>]  89.02K  --.-KB/s    in 0.02s
#
# 2023-06-08 06:06:05 (3.79 MB/s) - ‘owlvit-base-patch32’ saved [91153/91153]

# %%
# !pip install -q gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 74.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 28.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.6 MB/s eta 0:00:00
# ...

# %%
cd ../..
# Out:
# /content/segment_anything_webui

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.3 MB/s eta 0:00:00
# ...

# %%
# !python app.py
# Out:
# 2023-06-08 06:13:40.056843: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2052, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/segment_anything_webui/app.py", line 195, in <module>
#     demo.launch()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1969, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2054, in block_thread
#     print("Keyboard interruption in main thread... closing server.")
# KeyboardInterrupt
# ^C

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.7/611.7 kB 12.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # load a pretrained YOLOv8n model
results = model.predict(source="https://ultralytics.com/images/bus.jpg")
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
boxes = results[0].boxes

# %%
boxes.cls
# Out:
# tensor([ 5.,  0.,  0.,  0., 11.,  0.], device='cuda:0')

# %%
names = model.names

# %%
for r in results:
    for c in r.boxes.cls:
        print(names[int(c)])
# Out:
# bus
# person
# person
# person
# stop sign
# person

# %%
probs = results[0].probs

# %%
probs

# %%
results
# Out:
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
round(100 * max(boxes.conf.tolist()),2)
# Out:
# 87.05

# %%
results = model.predict(source="1_gun_1113_14_52_img_000013.png")
# Out:
# image 1/1 /content/1_gun_1113_14_52_img_000013.png: 352x640 1 person, 2 cars, 1 truck, 11.5ms
# Speed: 3.1ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
predicted_class = []
for r in results:
    for c in r.boxes.cls:
        predicted_class.append(names[int(c)])
predicted_class
# Out:
# ['person', 'car', 'truck', 'car']

# %%
round(100 * max(boxes.conf.tolist()),2)
# Out:
# 87.05

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 5.4 MB/s eta 0:00:00
# ...

# %%
# !Authorization: Bearer "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!"
# Out:
# /bin/bash: Authorization:: command not found

# %%
# !curl https://api.openai.com/v1/moderations \
  -X POST \
  -H "Content-Type: application/json" \
  -H "Authorization: Bearer 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" \
  -d '{"input": "Sample text goes here"}'
# Out:
# {
#   "error": {
#     "message": "You exceeded your current quota, please check your plan and billing details.",
#     "type": "insufficient_quota",
#     "param": null,
#     "code": 429
#   }
# }

# %%
# !curl https://api.openai.com/v1/models \
  -H "Authorization: Bearer 217dddc83301424b85e36306f9ff515b" \
  -H "OpenAI-Organization: https://spherex-gpt3.openai.azure.com/"
# Out:
# {
#   "error": {
#     "message": "Incorrect API key provided: 217dddc8********************515b. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
