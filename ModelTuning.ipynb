# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

# %matplotlib inline

# %%
# Importing Training Set
dataset_train = pd.read_csv('/content/gdrive/My Drive/datasets/GOOG.csv')

print(dataset_train.head())

# Select features (columns) to be involved intro training and predictions
cols = list(dataset_train)[1:6]

# Extract dates (will be used in visualization)
datelist_train = list(dataset_train['Date'])
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

print(datelist_train)

print('Training set shape == {}'.format(dataset_train.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(cols))
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2008-08-22  244.832306  246.515991  ...  244.379013  244.379013  4611500
# 1  2008-08-25  242.147369  247.572037  ...  240.603165  240.603165  4043600
# 2  2008-08-26  240.827316  240.827316  ...  236.194687  236.194687  6641100
# 3  2008-08-27  235.980484  236.528427  ...  233.415100  233.415100  8807000
# 4  2008-08-28  235.362808  237.335403  ...  236.005386  236.005386  6082000
#
# [5 rows x 7 columns]
# [datetime.date(2008, 8, 22), datetime.date(2008, 8, 25), datetime.date(2008, 8, 26), datetime.date(2008, 8, 27), datetime.date(2008, 8, 28), datetime.date(2008, 8, 29), datetime.date(2008, 9, 2), datetime.date(2008, 9, 3), datetime.date(2008, 9, 4), datetime.date(2008, 9, 5), datetime.date(2008, 9, 8), datetime.date(2008, 9, 9), datetime.date(2008, 9, 10), datetime.date(2008, 9, 11), datetime.date(2008, 9, 12), datetime.date(2008, 9, 15), datetime.date(2008, 9, 16), datetime.date(2008, 9, 17), datetime.date(2008, 9, 18), datetime.date(2008, 9, 19), datetime.date(2008, 9, 22), datetime.date(2008, 9, 23), datetime.date(2008, 9, 24), datetime.date(2008, 9, 25), datetime.date(2008, 9, 26), datetime.date(2008, 9, 29), datetime.date(2008, 9, 30), datetime.date(2008, 10, 1), datetime.date(2008, 10, 2), datetime.date(2008, 10, 3), datetime.date(2008, 10, 6), datetime.date(2008, 10, 7), datetime.date(2008, 10, 8), datetime.date(2008, 10, 9), datetime.date(2008, 10, 10), datetime.date(2008, 10, 13), datetime.date(2008, 10, 14), datetime.date(2008, 10, 15), datetime.date(2008, 10, 16), datetime.date(2008, 10, 17), datetime.date(2008, 10, 20), datetime.date(2008, 10, 21), datetime.date(2008, 10, 22), datetime.date(2008, 10, 23), datetime.date(2008, 10, 24), datetime.date(2008, 10, 27), datetime.date(2008, 10, 28), datetime.date(2008, 10, 29), datetime.date(2008, 10, 30), datetime.date(2008, 10, 31), datetime.date(2008, 11, 3), datetime.date(2008, 11, 4), datetime.date(2008, 11, 5), datetime.date(2008, 11, 6), datetime.date(2008, 11, 7), datetime.date(2008, 11, 10), datetime.date(2008, 11, 11), datetime.date(2008, 11, 12), datetime.date(2008, 11, 13), datetime.date(2008, 11, 14), datetime.date(2008, 11, 17), datetime.date(2008, 11, 18), datetime.date(2008, 11, 19), datetime.date(2008, 11, 20), datetime.date(2008, 11, 21), datetime.date(2008, 11, 24), datetime.date(2008, 11, 25), datetime.date(2008, 11, 26), datetime.date(2008, 11, 28), datetime.date(2008, 12, 1), datetime.date(2008, 12, 2), datetime.date(2008, 12, 3), datetime.date(2008, 12, 4), datetime.date(2008, 12, 5), datetime.date(2008, 12, 8), datetime.date(2008, 12, 9), datetime.date(2008, 12, 10), datetime.date(2008, 12, 11), datetime.date(2008, 12, 12), datetime.date(2008, 12, 15), datetime.date(2008, 12, 16), datetime.date(2008, 12, 17), datetime.date(2008, 12, 18), datetime.date(2008, 12, 19), datetime.date(2008, 12, 22), datetime.date(2008, 12, 23), datetime.date(2008, 12, 24), datetime.date(2008, 12, 26), datetime.date(2008, 12, 29), datetime.date(2008, 12, 30), datetime.date(2008, 12, 31), datetime.date(2009, 1, 2), datetime.date(2009, 1, 5), datetime.date(2009, 1, 6), datetime.date(2009, 1, 7), datetime.date(2009, 1, 8), datetime.date(2009, 1, 9), datetime.date(2009, 1, 12), datetime.date(2009, 1, 13), datetime.date(2009, 1, 14), datetime.date(2009, 1, 15), datetime.date(2009, 1, 16), datetime.date(2009, 1, 20), datetime.date(2009, 1, 21), datetime.date(2009, 1, 22), datetime.date(2009, 1, 23), datetime.date(2009, 1, 26), datetime.date(2009, 1, 27), datetime.date(2009, 1, 28), datetime.date(2009, 1, 29), datetime.date(2009, 1, 30), datetime.date(2009, 2, 2), datetime.date(2009, 2, 3), datetime.date(2009, 2, 4), datetime.date(2009, 2, 5), datetime.date(2009, 2, 6), datetime.date(2009, 2, 9), datetime.date(2009, 2, 10), datetime.date(2009, 2, 11), datetime.date(2009, 2, 12), datetime.date(2009, 2, 13), datetime.date(2009, 2, 17), datetime.date(2009, 2, 18), datetime.date(2009, 2, 19), datetime.date(2009, 2, 20), datetime.date(2009, 2, 23), datetime.date(2009, 2, 24), datetime.date(2009, 2, 25), datetime.date(2009, 2, 26), datetime.date(2009, 2, 27), datetime.date(2009, 3, 2), datetime.date(2009, 3, 3), datetime.date(2009, 3, 4), datetime.date(2009, 3, 5), datetime.date(2009, 3, 6), datetime.date(2009, 3, 9), datetime.date(2009, 3, 10), datetime.date(2009, 3, 11), datetime.date(2009, 3, 12), datetime.date(2009, 3, 13), datetime.date(2009, 3, 16), datetime.date(2009, 3, 17), da ...
# Training set shape == (2998, 7)
# All timestamps == 2998
# Featured selected: ['Open', 'High', 'Low', 'Close', 'Adj Close']

# %%
dataset_train = dataset_train[cols].astype(str)
for i in cols:
    for j in range(0, len(dataset_train)):
        dataset_train[i][j] = dataset_train[i][j].replace(',', '')

dataset_train = dataset_train.astype(float)

# Using multiple features (predictors)
training_set = dataset_train.values

print('Shape of training set == {}.'.format(training_set.shape))
training_set
# Out:
# Shape of training set == (2998, 5).
# array([[ 244.832306,  246.515991,  243.82608 ,  244.379013,  244.379013],
#        [ 242.147369,  247.572037,  239.850983,  240.603165,  240.603165],
#        [ 240.827316,  240.827316,  234.416351,  236.194687,  236.194687],
#        ...,
#        [1521.619995, 1523.439941, 1498.420044, 1515.550049, 1515.550049],
#        [1515.26001 , 1570.290039, 1503.599976, 1565.719971, 1565.719971],
#        [1586.98999 , 1586.98999 , 1554.280029, 1558.420044, 1558.420044]])

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
training_set_scaled = sc.fit_transform(training_set)

training_set_scaled
# Out:
# array([[-1.03988439, -1.04063569, -1.03585083, -1.04020883, -1.04020883],
#        [-1.04718024, -1.03779417, -1.04674835, -1.05045548, -1.05045548],
#        [-1.05076726, -1.05594234, -1.06164711, -1.06241891, -1.06241891],
#        ...,
#        [ 2.42956569,  2.39521192,  2.40355288,  2.40940922,  2.40940922],
#        [ 2.41228353,  2.52127252,  2.41775339,  2.54555696,  2.54555696],
#        [ 2.60719737,  2.56620745,  2.5566901 ,  2.52574691,  2.52574691]])

# %%
# Creating a data structure with 90 timestamps and 1 output
X_train = []
y_train = []

n_future = 60   # Number of days we want to predict into the future (lag size)
n_past = 90     # Number of past days we want to use to predict the future

for i in range(n_past, len(training_set_scaled) - n_future +1):
    X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
    y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)



print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (2849, 90, 4).
# y_train shape == (2849, 1).

# %%
# Import Libraries and packages from Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.layers import Bidirectional

# %%
# (window size, features)
# Initializing the Neural Network based on LSTM
model = Sequential()

# Adding 1st LSTM layer
                                                              #(window size, 1)
model.add(Bidirectional(LSTM(units=512, return_sequences=True, kernel_initializer='random_normal', input_shape=(n_past, dataset_train.shape[1]-1))))

# Adding 2nd LSTM layer
model.add(Bidirectional(LSTM(units=128, kernel_initializer='random_normal', return_sequences=True)))

# Adding Dropout
model.add(Dropout(0.25))


# # Adding 2nd LSTM layer
# model.add(LSTM(units=64, kernel_initializer='random_normal', return_sequences=True))

# # # Adding Dropout
# # model.add(Dropout(0.25))


# # Adding 2nd LSTM layer
# model.add(LSTM(units=32, return_sequences=False))

# # # Adding Dropout
# # model.add(Dropout(0.25))


# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
# %%time
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

history = model.fit(X_train, y_train, shuffle=True, epochs=30, callbacks=[es, rlr, mcp, tb], validation_split=0.3, verbose=1, batch_size=32)
# Out:
# Epoch 1/30
# 63/63 [==============================] - ETA: 0s - loss: 0.1835
# Epoch 00001: val_loss improved from inf to 0.25338, saving model to weights.h5
# 63/63 [==============================] - 209s 3s/step - loss: 0.1835 - val_loss: 0.2534
# Epoch 2/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0264
# Epoch 00002: val_loss did not improve from 0.25338
# 63/63 [==============================] - 208s 3s/step - loss: 0.0264 - val_loss: 0.3781
# Epoch 3/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0235
# Epoch 00003: val_loss did not improve from 0.25338
# 63/63 [==============================] - 202s 3s/step - loss: 0.0235 - val_loss: 0.4120
# Epoch 4/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0223
# Epoch 00004: val_loss improved from 0.25338 to 0.23686, saving model to weights.h5
# 63/63 [==============================] - 200s 3s/step - loss: 0.0223 - val_loss: 0.2369
# Epoch 5/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0208
# Epoch 00005: val_loss improved from 0.23686 to 0.21072, saving model to weights.h5
# 63/63 [==============================] - 203s 3s/step - loss: 0.0208 - val_loss: 0.2107
# Epoch 6/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 00006: val_loss improved from 0.21072 to 0.20139, saving model to weights.h5
# 63/63 [==============================] - 199s 3s/step - loss: 0.0215 - val_loss: 0.2014
# Epoch 7/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 00007: val_loss improved from 0.20139 to 0.14650, saving model to weights.h5
# 63/63 [==============================] - 202s 3s/step - loss: 0.0183 - val_loss: 0.1465
# Epoch 8/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 00008: val_loss did not improve from 0.14650
# 63/63 [==============================] - 206s 3s/step - loss: 0.0180 - val_loss: 0.3207
# Epoch 9/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 00009: val_loss did not improve from 0.14650
# 63/63 [==============================] - 204s 3s/step - loss: 0.0213 - val_loss: 0.5196
# Epoch 10/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0182
# Epoch 00010: val_loss did not improve from 0.14650
# 63/63 [==============================] - 202s 3s/step - loss: 0.0182 - val_loss: 0.2327
# Epoch 11/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 00011: val_loss did not improve from 0.14650
# 63/63 [==============================] - 205s 3s/step - loss: 0.0162 - val_loss: 0.1875
# Epoch 12/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 00012: val_loss did not improve from 0.14650
# 63/63 [==============================] - 202s 3s/step - loss: 0.0141 - val_loss: 0.1717
# Epoch 13/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 00013: val_loss did not improve from 0.14650
# 63/63 [==============================] - 201s 3s/step - loss: 0.0161 - val_loss: 0.1583
# Epoch 14/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 00014: val_loss improved from 0.14650 to 0.11652, saving model to weights.h5
# 63/63 [==============================] - 205s 3s/step - loss: 0.0120 - val_loss: 0.1165
# Epoch 15/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 00015: val_loss did not improve from 0.11652
# 63/63 [==============================] - 202s 3s/step - loss: 0.0134 - val_loss: 0.1406
# Epoch 16/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 00016: val_loss did not improve from 0.11652
# 63/63 [==============================] - 202s 3s/step - loss: 0.0124 - val_loss: 0.1182
# Epoch 17/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 00017: val_loss improved from 0.11652 to 0.11480, saving model to weights.h5
# 63/63 [==============================] - 207s 3s/step - loss: 0.0203 - val_loss: 0.1148
# Epoch 18/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 00018: val_loss did not improve from 0.11480
# 63/63 [==============================] - 203s 3s/step - loss: 0.0173 - val_loss: 0.1477
# Epoch 19/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0175
# Epoch 00019: val_loss did not improve from 0.11480
# 63/63 [==============================] - 202s 3s/step - loss: 0.0175 - val_loss: 0.1241
# Epoch 20/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 00020: val_loss did not improve from 0.11480
# 63/63 [==============================] - 206s 3s/step - loss: 0.0120 - val_loss: 0.4780
# Epoch 21/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0177
# Epoch 00021: val_loss did not improve from 0.11480
# 63/63 [==============================] - 204s 3s/step - loss: 0.0177 - val_loss: 0.2086
# Epoch 22/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0181
# Epoch 00022: val_loss improved from 0.11480 to 0.09036, saving model to weights.h5
# 63/63 [==============================] - 202s 3s/step - loss: 0.0181 - val_loss: 0.0904
# Epoch 23/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 00023: val_loss did not improve from 0.09036
# 63/63 [==============================] - 206s 3s/step - loss: 0.0164 - val_loss: 0.1286
# Epoch 24/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0181
# Epoch 00024: val_loss did not improve from 0.09036
# 63/63 [==============================] - 201s 3s/step - loss: 0.0181 - val_loss: 0.3292
# Epoch 25/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 00025: val_loss did not improve from 0.09036
# 63/63 [==============================] - 202s 3s/step - loss: 0.0161 - val_loss: 0.4447
# Epoch 26/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 00026: val_loss did not improve from 0.09036
# 63/63 [==============================] - 206s 3s/step - loss: 0.0120 - val_loss: 0.2888
# Epoch 27/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 00027: val_loss did not improve from 0.09036
# 63/63 [==============================] - 201s 3s/step - loss: 0.0111 - val_loss: 0.5487
# Epoch 28/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 00028: val_loss did not improve from 0.09036
# 63/63 [==============================] - 201s 3s/step - loss: 0.0107 - val_loss: 0.2835
# Epoch 29/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 00029: val_loss did not improve from 0.09036
# 63/63 [==============================] - 207s 3s/step - loss: 0.0103 - val_loss: 0.2286
# Epoch 30/30
# 63/63 [==============================] - ETA: 0s - loss: 0.0106
# Epoch 00030: val_loss did not improve from 0.09036
# 63/63 [==============================] - 201s 3s/step - loss: 0.0106 - val_loss: 0.2663
# CPU times: user 3h 13min 27s, sys: 5min 4s, total: 3h 18min 31s
# Wall time: 1h 43min 21s

# %%
# Generate list of sequence of days for predictions
datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()
print(datelist_future)
'''
Remeber, we have datelist_train from begining.
'''
print("___________________________________________________________________________________________")
# Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
datelist_future_ = []
for this_timestamp in datelist_future:
    datelist_future_.append(this_timestamp.date())
# Out:
# [Timestamp('2020-07-21 00:00:00', freq='D'), Timestamp('2020-07-22 00:00:00', freq='D'), Timestamp('2020-07-23 00:00:00', freq='D'), Timestamp('2020-07-24 00:00:00', freq='D'), Timestamp('2020-07-25 00:00:00', freq='D'), Timestamp('2020-07-26 00:00:00', freq='D'), Timestamp('2020-07-27 00:00:00', freq='D'), Timestamp('2020-07-28 00:00:00', freq='D'), Timestamp('2020-07-29 00:00:00', freq='D'), Timestamp('2020-07-30 00:00:00', freq='D'), Timestamp('2020-07-31 00:00:00', freq='D'), Timestamp('2020-08-01 00:00:00', freq='D'), Timestamp('2020-08-02 00:00:00', freq='D'), Timestamp('2020-08-03 00:00:00', freq='D'), Timestamp('2020-08-04 00:00:00', freq='D'), Timestamp('2020-08-05 00:00:00', freq='D'), Timestamp('2020-08-06 00:00:00', freq='D'), Timestamp('2020-08-07 00:00:00', freq='D'), Timestamp('2020-08-08 00:00:00', freq='D'), Timestamp('2020-08-09 00:00:00', freq='D'), Timestamp('2020-08-10 00:00:00', freq='D'), Timestamp('2020-08-11 00:00:00', freq='D'), Timestamp('2020-08-12 00:00:00', freq='D'), Timestamp('2020-08-13 00:00:00', freq='D'), Timestamp('2020-08-14 00:00:00', freq='D'), Timestamp('2020-08-15 00:00:00', freq='D'), Timestamp('2020-08-16 00:00:00', freq='D'), Timestamp('2020-08-17 00:00:00', freq='D'), Timestamp('2020-08-18 00:00:00', freq='D'), Timestamp('2020-08-19 00:00:00', freq='D'), Timestamp('2020-08-20 00:00:00', freq='D'), Timestamp('2020-08-21 00:00:00', freq='D'), Timestamp('2020-08-22 00:00:00', freq='D'), Timestamp('2020-08-23 00:00:00', freq='D'), Timestamp('2020-08-24 00:00:00', freq='D'), Timestamp('2020-08-25 00:00:00', freq='D'), Timestamp('2020-08-26 00:00:00', freq='D'), Timestamp('2020-08-27 00:00:00', freq='D'), Timestamp('2020-08-28 00:00:00', freq='D'), Timestamp('2020-08-29 00:00:00', freq='D'), Timestamp('2020-08-30 00:00:00', freq='D'), Timestamp('2020-08-31 00:00:00', freq='D'), Timestamp('2020-09-01 00:00:00', freq='D'), Timestamp('2020-09-02 00:00:00', freq='D'), Timestamp('2020-09-03 00:00:00', freq='D'), Timestamp('2020-09-04 00:00:00', freq='D'), Timestamp('2020-09-05 00:00:00', freq='D'), Timestamp('2020-09-06 00:00:00', freq='D'), Timestamp('2020-09-07 00:00:00', freq='D'), Timestamp('2020-09-08 00:00:00', freq='D'), Timestamp('2020-09-09 00:00:00', freq='D'), Timestamp('2020-09-10 00:00:00', freq='D'), Timestamp('2020-09-11 00:00:00', freq='D'), Timestamp('2020-09-12 00:00:00', freq='D'), Timestamp('2020-09-13 00:00:00', freq='D'), Timestamp('2020-09-14 00:00:00', freq='D'), Timestamp('2020-09-15 00:00:00', freq='D'), Timestamp('2020-09-16 00:00:00', freq='D'), Timestamp('2020-09-17 00:00:00', freq='D'), Timestamp('2020-09-18 00:00:00', freq='D')]
# ___________________________________________________________________________________________

# %%
sc_predict = StandardScaler()
sc_predict.fit_transform(training_set[:, 0:1])
# Out:
# array([[-1.03988439],
#        [-1.04718024],
#        [-1.05076726],
#        ...,
#        [ 2.42956569],
#        [ 2.41228353],
#        [ 2.60719737]])

# %%
# Perform predictions
predictions_future = model.predict(X_train[-n_future:])

predictions_train = model.predict(X_train[n_past:])

# %%
# Inverse the predictions to original measurements

# ---> Special function: convert <datetime.date> to <Timestamp>
def datetime_to_timestamp(x):
    '''
        x : a given datetime value (datetime.date)
    '''
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')


y_pred_future = sc_predict.inverse_transform(predictions_future)
y_pred_train = sc_predict.inverse_transform(predictions_train)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Open']).set_index(pd.Series(datelist_future))
PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['Open']).set_index(pd.Series(datelist_train[2 * n_past + n_future -1:]))

# Convert <datetime.date> to <Timestamp> for PREDCITION_TRAIN
PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-8593ca1452ca> in <module>()
#      13 y_pred_train = sc_predict.inverse_transform(predictions_train)
#      14
# ---> 15 PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Open']).set_index(pd.Series(datelist_future))
#      16 PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['Open']).set_index(pd.Series(datelist_train[2 * n_past + n_future -1:]))
#      17
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     188     # by definition an array here
#     189     # the dtypes will be coerced to a single dtype
# --> 190     values = _prep_ndarray(values, copy=copy)
#     191
#     192     if dtype is not None:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in _prep_ndarray(values, copy)
#     322         values = values.reshape((values.shape[0], 1))
#     323     elif values.ndim != 2:
# --> 324         raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     325
#     326     return values
#
# ValueError: Must pass 2-d input. shape=(60, 90, 1)

# %%
# Parse training set timestamp for better visualization
dataset_train = pd.DataFrame(dataset_train, columns=cols)
dataset_train.index = datelist_train
dataset_train.index = pd.to_datetime(dataset_train.index)

# %%
# Set plot size 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 5

# Plot parameters
START_DATE_FOR_PLOTTING = '2012-06-01'

plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['Open'], color='r', label='Predicted Stock Price')
plt.plot(PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:].index, PREDICTION_TRAIN.loc[START_DATE_FOR_PLOTTING:]['Open'], color='orange', label='Training predictions')
plt.plot(dataset_train.loc[START_DATE_FOR_PLOTTING:].index, dataset_train.loc[START_DATE_FOR_PLOTTING:]['Open'], color='b', label='Actual Stock Price')

plt.axvline(x = min(PREDICTIONS_FUTURE.index), color='green', linewidth=2, linestyle='--')

plt.grid(which='major', color='#cccccc', alpha=0.5)

plt.legend(shadow=True)
plt.title('Predcitions and Acutal Stock Prices', family='Arial', fontsize=12)
plt.xlabel('Timeline', family='Arial', fontsize=10)
plt.ylabel('Stock Price Value', family='Arial', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.show()
