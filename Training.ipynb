# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# !cp -r /content/gdrive/MyDrive/Try .

# %%
# %cd Try
# Out:
# /content/Try

# %%
# !python Final.py
# Out:
# 2021-06-07 07:08:46.269178: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "Final.py", line 33, in <module>
#     from gru import GRU
#   File "/content/Try/gru.py", line 15, in <module>
#     from keras.engine import Layer
# ImportError: cannot import name 'Layer' from 'keras.engine' (/usr/local/lib/python3.7/dist-packages/keras/engine/__init__.py)
